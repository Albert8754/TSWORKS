# %% [markdown]
# <a href="https://colab.research.google.com/github/Albert8754/TSWORKS/blob/main/complaince.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv("/content/verafin.txt",header = 0,delimiter = '|')

# %%
now = datetime.now ()
df
# Out:
#      Institution Number           Customer Number  Account Branch Number  \
# 0                     0  4ixyI-F4iHZNxV---kPF-Bg-                      1
# 1                     0  4iNod4GSGElDtk--0VHF-Bg-                      1
# 2                     0  4iNod4GSGElDtk--0VHF-Bg-                      1
# 3                     0  4ij26NwJGqpt0V---kiF-Bg-                      1
# 4                     0  4iNod4GSGElDtk--0VHF-Bg-                      1
# ..                  ...                       ...                    ...
# 168                   0  4iNnE65wwh-qdV---kuF-Bg-                      1
# 169                   0  4ij1JO9lOYB5zF---kHF-Bg-                      1
# 170                   0  4j-9ESKAp_KYTF---kqF-Bg-                      1
# 171                   0  4jiWeqIlvafQHk---kXF-Bg-                      1
# 172                   0  4jkAISNqWAOCdk----LF-Bg-                      1
#
#      Account Number  External Number Account Type  Code  \
# ...

# %%
df.assign(md5_values=1 ,processed_flag= now ,processed_date= now).head()
# Out:
#    Institution Number           Customer Number  Account Branch Number  \
# 0                   0  4ixyI-F4iHZNxV---kPF-Bg-                      1
# 1                   0  4iNod4GSGElDtk--0VHF-Bg-                      1
# 2                   0  4iNod4GSGElDtk--0VHF-Bg-                      1
# 3                   0  4ij26NwJGqpt0V---kiF-Bg-                      1
# 4                   0  4iNod4GSGElDtk--0VHF-Bg-                      1
#
#    Account Number  External Number Account Type  Code  \
# 0    300000000963     300000000963                DDA
# 1    200000000836     200000000836                SAV
# 2    200000001069     200000001069                SAV
# 3    200000002046     200000002046                SAV
# 4    300000000665     300000000665                DDA
#
#    Account Type Code Description Account Subtype Account Purpose Flag  \
# 0                            NaN         DDA1001             PERSONAL
# ...
